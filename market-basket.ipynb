# %%
import pandas as pd
import numpy as np

from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
# load the data
df_fiction = pd.read_csv('df_fiction.csv')
df_fiction.head()
# Out:
#                      Title             authors            categories  \
# 0  Tess and the Highlander  ['May Mcgoldrick']  ['Juvenile Fiction']
# 1  Tess and the Highlander  ['May Mcgoldrick']  ['Juvenile Fiction']
# 2  Tess and the Highlander  ['May Mcgoldrick']  ['Juvenile Fiction']
# 3  Tess and the Highlander  ['May Mcgoldrick']  ['Juvenile Fiction']
# 4  Tess and the Highlander  ['May Mcgoldrick']  ['Juvenile Fiction']
#
#            Id         User_id              profileName review/helpfulness  \
# 0  006000486X  A2VCGJLKGK2WJJ           Rebecca Herman              17/18
# 1  006000486X   AVWFMN5CELC8Q                    sarah                6/6
# 2  006000486X  A37XYM3KSEIDLS  jaina_solo "jaina_solo"                6/6
# 3  006000486X  A1IQK80SXVPAWW            atlantis_girl                4/4
# 4  006000486X  A1PI0GN5N7M3GF           Patricia Ahern                5/6
#
#    review/score                                        review/text
# 0           5.0  Tess was washed ashore on the Isle of May duri...
# 1           4.0  This is an engaging a count of life of Tess a ...
# 2           5.0  This book was a perfect historical romance for...
# 3           5.0  I loved everything about this book - the setti...
# 4           5.0  This book was spellbinding! Filled with advent...

# %%
# Select only relevant columns (user_id and book_id)
user_book_df = df_fiction[['User_id', 'Title']].drop_duplicates()

# Display a sample
print(user_book_df.head(20))
# Out:
#            User_id                               Title
# 0   A2VCGJLKGK2WJJ             Tess and the Highlander
# 1    AVWFMN5CELC8Q             Tess and the Highlander
# 2   A37XYM3KSEIDLS             Tess and the Highlander
# 3   A1IQK80SXVPAWW             Tess and the Highlander
# 4   A1PI0GN5N7M3GF             Tess and the Highlander
# 5   A1H72DULSEGDX7             Tess and the Highlander
# 6   A1PQJ6IPEQB3CD             Tess and the Highlander
# 7   A3MOFUL6BIMK5A             Tess and the Highlander
# 8   A1C9QFE7N8YCF4             Tess and the Highlander
# 9    ANQHSC4OSF4SA             Tess and the Highlander
# 10  A1BXZTM5IFHODP             Tess and the Highlander
# 11  A148K8LOPWE6RK             Tess and the Highlander
# 12  A1NZ6D6SD7B1AP             Tess and the Highlander
# 13  A3FTN134G68ZJ4             Tess and the Highlander
# 14  A1QY2X792MF802             Tess and the Highlander
# 15  A1DJMMJ4OQ2712             Tess and the Highlander
# 16   ADB0JID2XRFYR  Night World: Daughters Of Darkness
# 17  A1V0SFB3AXM8JK  Night World: Daughters Of Darkness
# 18   AODBNCTX9L1L5  Night World: Daughters Of Darkness
# 19  A107F528SN3XJU  Night World: Daughters Of Darkness

# %%
user_book_df.shape
# Out:
# (91013, 2)

# %% [markdown]
# ## some basic testing

# %%
from itertools import combinations
from collections import Counter

# %%
# Create a dictionary where keys = user_ids and values = lists of book_ids they reviewed
user_books = user_book_df.groupby('User_id')['Title'].apply(list)
user_books.head()
# Out:
# User_id
# A00290423P2GEY37XWVAW                [The Adventures of Super Diaper Baby]
# A00538832OF17R8Q8JHTB              [Harry Potter and The Sorcerer's Stone]
# A00540411RKGTDNU543WS                                         [The Hobbit]
# A0056746VLX0I5VJCFN6     [If You Give a Mouse a Cookie (Book and Audio ...
# A00878773S2MNB00COHKV                                         [The Hobbit]
# Name: Title, dtype: object

# %%
# show the user with the most reviews and the number of reviews
user_books.apply(len).idxmax(), user_books.apply(len).max()
# Out:
# ('A14OJS0VWMOSWO', np.int64(233))

# %%
# show the list of books reviewed by the user with the most reviews
user_books[user_books.apply(len).idxmax()]
# Out:
# ["The National Review Treasury of Classic Children's Literature",
#  'Casey at the Bat',
#  'Summer of My German Soldier',
#  'The witch of blackbird pond (A Dell yearling book)',
#  'The Burgess bird book for children',
#  'Seaman: The Dog Who Explored the West With Lewis and Clark (Peachtree Junior Publication)',
#  'Mio, My Son',
#  'The Moon in My Room (Willowbe Woods Campfire Stories)',
#  'The Not Me Monster (Willowbe Woods Campfire Stories, 2)',
#  'The legend of Sleepy Hollow,',
#  'Pig on a Swing',
#  'The Night Before Christmas, The (Wee Books for Wee Folk)',
#  'Snack Attack',
#  'The Golden Egg Book (Big Little Golden Book)',
#  'Four Things My Geeky-Jock-of-a-Best Friend Must Do in Europe',
#  'Boswell wide-awake',
#  'How I Spent My Summer Holidays',
#  'Marky and the Seagull',
#  'Peter Raven: Under Fire (SIGNED)',
#  'Cuba 15',
#  "Saffy's Angel (Costa Children's Book Award (Awards))",
#  'The Shy Stegosaurus of Cricket Creek',
#  'Revenge on Rairarubia',
#  'Owen & Mzee: The True Story of a Remarkable Friendship',
#  'Angus and the Hidden Fort',
#  "If I Have a Wicked Stepmother, Where's My Prince?",
#  'Abduction',
#  "It's Great to be a Ghost",
#  'The Animal Hedge',
#  'A Thousand Ships : Age of Bronze, Volume One',
#  'Delicate Creatures',
#  'Maximum Ride: The Angel Experiment',
#  "Time to Tell 'Em Off! A Pocket Guide to Overcoming Peer Ridicule",
#  'Jabberwocky',
#  'The Staircase',
#  'Lilies On The Moon',
#  'Numbering All the Bones',
#  'The Deliverance of Dancing Bears',
#  'Fibblestax',
#  "The Adventures of Pinocchio (World's Classics)",
#  'Utterly Me, Clarice Bean',
#  'The Slippery Slope',
#  'The Secret Garden',
#  'The Thanksgiving Visitor',
#  'The Secret Within, The',
#  'Race the Wind! (Willow King) (No. 2)',
#  "Harry Potter and The Sorcerer's Stone",
#  'Taprarmiuni Kassiyulriit: Stebbins Dance Festival',
#  'The Monster Run',
#  'Pete the Sheep-Sheep',
#  'No Haircut Today!',
#  'Hanging on to Max',
#  'Who Asked the Moon to Dinner?',
#  'Private Peaceful (After Words)',
#  "Alice's Adventures in Wonderland (Aladdin Classics)",
#  'The Boy Who Looked Like Lincoln',
#  'Little Pig is capable',
#  'Adventures of Riley--Tigers in Terai',
#  'Miracles on Maple Hill',
#  'Riders of the Dawn: Library Edition',
#  'The Long Walk',
#  'Monster toddler',
#  'Persephone the Ladybug',
#  'Akiko and the Alpha Centauri 5000 (Akiko)',
#  'CORNER OF THE UNIVERSE, A',
#  'RULER OF THE REALM',
#  'Cat Book',
#  'Parting Gifts',
#  'Millie in the Meadow',
#  'The Girl',
#  'The Year of My Indian Prince',
#  'Squizzy the Black Squirrel: A Fabulous Fable of Friendship',
#  'A Piece of the Sky',
#  'A Day in the Life of Murphy (Bccb Blue Ribbon Picture Book Awards (Awards))',
#  'Escape from the Holocaust (Roseman, Kenneth. Do-It-Yourself Jewish Adventure Series.)',
#  'Boys in control (Boys-girls battle series)',
#  'Fortune in Your Cookies',
#  'The Sidewalk Rescue',
#  "Cackle Cook's Monster Stew (Family Storytime)",
#  'Postcards to Father Abraham',
#  'The Boy Trap',
#  'The Patch',
#  'Thirteen Ways to Sink a Sub',
#  'Terrible Times: Book 3, The Eddie Dickens Trilogy',
#  'Ashes of Roses',
#  'Little Golden Book Collection: Farm Tales (Little Golden Book Treasury)',
#  'Traction Man Is Here! (Boston Globe-Horn Book Awards (Awards))',
#  'Freight Train/Tren de carga (Spanish Edition)',
#  'Hide and Seek',
#  'Dear Big, Mean, Ugly Monster',
#  'How Hilda Hushed Her Hiccups: Letter-Sound Listen & Retell Adventure S',
#  'Was It the Chocolate Pudding?: A Story For Little Kids About Divorce',
#  'Becoming Chloe',
#  'The adventures of Pinocchio, (Illustrated junior library)',
#  'Treasure Island; (Easy reading books: upper-grade interest)',
#  'The Heroic Adventure of Hercules Amsterdam',
#  'The Witch of Blackbird Pond',
#  'The Three Little Puppies and the Big Bad Flea',
#  'Paw Prints Through The Years',
#  "Diary of a Wombat (Ala Notable Children's Books. Younger Readers (Awards))",
#  'A Brief Chapter in My Impossible Life',
#  'The House & Garden Book of Country Rooms (House & Garden Series)',
#  'A visit from Santa Claus',
#  'Loamhedge: Redwall, Book 16',
#  'Guitar Highway Rose',
#  'Boomer to the Rescue',
#  'Henry and Mudge and the Funny Lunch Level 2 Reader (Henry and Mudge Ready-to-Read)',
#  'The Loathsome Dragon',
#  'The Boy Who Stuck Out His Tongue: A Yiddish Folk Tale',
#  'War Horse',
#  'Young Classics - Peter Pan',
#  'A Confused Hanukkah: An Original Story of Chelm',
#  'There Are 508 Stars In The Sky',
#  'I Heard a Little Baa',
#  'The Birdwatchers',
#  'Farmer McPeepers and His Missing Milk Cows',
#  'Just You and Me',
#  'Amber Spyglass (10th Anniversary Ed)',
#  'Sweet Dreams, Douglas',
#  'The Secret of the Old Clock (Nancy Drew, Book 1)',
#  'King of Shadows',
#  "Mr. Pine's Mixed-up Signs",
#  "The Hidden Alphabet (Ala Notable Children's Books. Younger Readers (Awards))",
#  'How Tia Lola Came to (Visit) Stay (The Tia Lola Stories)',
#  'Riddle in the Mountain',
#  'The Folk Keeper (Jean Karl Books)',
#  'Braced2Bite',
#  'Creatures Journey Through Life',
#  'The Thanksgiving Door',
#  "I Don't Want to Be Lunch!",
#  'How I Survived My Summer Vacation: And Lived to Write the Story',
#  'Sally Goes to the Mountains',
#  'Blue Aliens an Adventure in Color',
#  'The little prince',
#  'A Passage To India (Turtleback School & Library Binding Edition)',
#  "Gwyneth's Secret Grandpa (Family History Adventures for Young Readers, 1)",
#  'The Great Cannon Beach Mouse Caper',
#  'Across A Dark & Wild Sea',
#  'The Prophet of Yonwood (Ember, Book 3)',
#  'The Things I Know Best',
#  'The Great Fuzz Frenzy',
#  "Noah's Castle",
#  'Beaver Steals Fire: A Salish Coyote Story',
#  'Witch Child (Turtleback School & Library Binding Edition)',
#  'Sweep Dreams',
#  'Adventures Of Pinocchio',
#  'Little Squarehead',
#  "Warlord's Puzzle, The (Warlord's Series)",
#  'Island of the Blue Dolphins',
#  'The Three Little Javelinas',
#  'What Marion Taught Willis (Follow Marion on Her Library Adventures!)',
#  "Daniel's Ride",
#  'Jade Green : A Ghost Story',
#  'Saying it Out Loud',
#  'Here in the World',
#  'Wave Me Goodbye',
#  '11,000 Years Lost',
#  'The Arnold Lobel Book of Mother Goose: A Treasury of More Than 300 Classic Nursery Rhymes',
#  'First Day (A Dewey Does book)',
#  "Tenggren's Golden tales from the arabian nights",
#  'Farseed (Seed Trilogy)',
#  'Blue Moon Mountain',
#  'Hotel Transylvania',
#  'Ancient Rhymes: a Dolphin Lullaby With CD (Audio) (John Denver & Kids!)',
#  'My Grandma Lives at the Airport',
#  'Reading with Dad',
#  'The Boxer: A Novel',
#  'Hooray for You!: A Celebration of You-Ness',
#  'Dr. Welch and the Great Grape Story',
#  "Bilbo's Last Song: At the Grey Havens",
#  'Leo the Lightning Bug',
#  "It's Me! (with Audio CD)",
#  "Disney's Storybook Collection (Disney Storybook Collections)",
#  'Who Needs Donuts?',
#  'The witch of Blackbird Pond (A Dell book)',
#  'Stories of Hope and Spirit',
#  "New York's Bravest",
#  'Shadowmancer',
#  'Milo Moments',
#  'You Are Here Kids & Family Internet Guide',
#  'It Rained All Day That Night',
#  "Glasses: Who Needs 'Em?",
#  'Never Talk to Strangers',
#  'Glitter & Greed: The Secret World of the Diamond Cartel',
#  'Tagger, Alone Along the Mystic River',
#  'Ame the Elephant: Terrorized by Evil Mice',
#  "Brian's Hunt",
#  'The Blue Hour',
#  'Does God Know How To Tie Shoes?',
#  'Chain Letter',
#  'King of the Wind',
#  'GLORIA The Christmas Angel',
#  "Ruby Lee The Bumble Bee: A Bee's Bit Of Wisdom",
#  'A Pacific Alphabet',
#  'The Littlest Frog (Littlest Series)',
#  'It All Began with a Bean',
#  "Mystery at Blackbeard's Cove",
#  'Stolen Sun',
#  'Evangeline Mudd and the Golden-Haired Apes of the Ikkinasti',
#  "mr. pine's purple house",
#  'Kendra Kandlestar and the Box of Whispers (Chronicles of Kendra Kandlestar, Book 1)',
#  'The Teacher Who Would Not Retire',
#  'Black Indians: A Hidden Heritage',
#  'The brothers Lionheart',
#  'Hildegarde and the Great Green Shirt Factory (Hildegarde series)',
#  'I Love You, Little One (Book and Audiocassette Tape) (Paperback)',
#  'Faerie Wars (Faerie Wars Chronicles)',
#  'Eldest (Inheritance, Book 2)',
#  'Saviors of the Bugle',
#  'Book Savvy',
#  'Talisman of Zandria',
#  'Before I Was Your Mother',
#  "Forest Friends' Five Senses",
#  'I Walk at Night',
#  'The Silver Crown',
#  'Chitty Chitty Bang Bang',
#  'Tin Can Man',
#  'I Know a Shy Fellow Who Swallowed a Cello',
#  'The Adventures of WonderBaby: From A to Z',
#  'The Year of the Dog: Tales from the Chinese Zodiac',
#  'EMILY',
#  'Punxsutawney Phyllis',
#  "Japanese Children's Favorite Stories",
#  'Tale of Despereaux',
#  'The Invisible Moose',
#  'Time Pieces: The Book of Times',
#  'Mysteries in Our National Parks: Over The Edge',
#  'The Baron of Grogzwig',
#  'Car Wash',
#  "Sometimes It's Turkey Sometimes It's Feathers",
#  "Nobody's Perfect",
#  'The World According to Humphrey',
#  'The Last Knight: An Introduction to Don Quixote']

# %%
# Create book pairs for each user
book_pairs = []
for books in user_books:
    if len(books) > 1:  # Only consider users who reviewed at least 2 books
        book_pairs.extend(combinations(sorted(books), 2))

# Count the occurrence of each book pair
pair_counts = Counter(book_pairs)

# Convert to a DataFrame
book_pair_df = pd.DataFrame(pair_counts.items(), columns=['book_pair', 'count'])

# Sort by most frequently reviewed together
book_pair_df = book_pair_df.sort_values(by='count', ascending=False)

# Display the top 10 most reviewed-together books
book_pair_df.head(10)
# Out:
#                                              book_pair  count
# 35   (Harry Potter and The Sorcerer's Stone, Harry ...    610
# 26   (The Monster At The End Of This Book, The mons...    359
# 14   (A visit from Santa Claus, The Night Before Ch...    327
# 0    (The Velveteen Rabbit, Or, How Toys Become Rea...    240
# 3    (The witch of Blackbird Pond (A Dell book), Th...    232
# 1    (The Witch of Blackbird Pond, The witch of Bla...    230
# 2    (The Witch of Blackbird Pond, The witch of bla...    230
# 823  (Blueberries for Sal, Blueberries for Sal (Chi...    114
# 182         (Mossflower, Mossflower (Redwall, Book 2))    106
# 15   (Little House on the Prairie, Little House on ...     99

# %%
book_pair_df.shape
# Out:
# (134564, 2)

# %% [markdown]
# ## Apply Association Rule Mining (Apriori or FP-Growth)

# %% [markdown]
# Convert Data into a Transaction Format
# The Apriori algorithm requires data in a basket format, where each row represents a user’s basket of reviewed books.

# %%
# %pip install mlxtend

# %%
# Convert user-book interactions into a list of transactions
transactions = user_book_df.groupby("User_id")["Title"].apply(list).tolist()
transactions[:5]
# Out:
# [['The Adventures of Super Diaper Baby'],
#  ["Harry Potter and The Sorcerer's Stone"],
#  ['The Hobbit'],
#  ['If You Give a Mouse a Cookie (Book and Audio CD) (Paperback)'],
#  ['The Hobbit']]

# %%
# Encode transactions into a binary format
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# Display a sample (binary matrix)
df_encoded.head()
# Out:
#    "Could Be Worse!" (Reading Rainbow Library)  "I'm Not Cute!"  "Miss Lou."  \
# 0                                        False            False        False
# 1                                        False            False        False
# 2                                        False            False        False
# 3                                        False            False        False
# 4                                        False            False        False
#
#    "National Velvet"  "The Best Mistake Ever and Other Stories  \
# 0              False                                     False
# 1              False                                     False
# 2              False                                     False
# 3              False                                     False
# 4              False                                     False
#
#    "Thy servant a dog"  'Morning Has Broken'  \
# 0                False                 False
# 1                False                 False
# 2                False                 False
# 3                False                 False
# 4                False                 False
#
#    .Hack//Legend of the Twilight Vol. 3  1 2 3  1, 2, I Love You  ...  \
# 0                                 False  False             False  ...
# 1                                 False  False             False  ...
# 2                                 False  False             False  ...
# 3                                 False  False             False  ...
# 4                                 False  False             False  ...
#
#    taran wanderer  the day the teacher went bananas  the fabulous flight  \
# 0           False                             False                False
# 1           False                             False                False
# 2           False                             False                False
# 3           False                             False                False
# 4           False                             False                False
#
#    the golden key  the lion's paw  the little riders  the secret hide-out  \
# 0           False           False              False                False
# 1           False           False              False                False
# 2           False           False              False                False
# 3           False           False              False                False
# 4           False           False              False                False
#
#    tom swift in the city of gold  toning the sweep   ttyl
# 0                          False             False  False
# 1                          False             False  False
# 2                          False             False  False
# 3                          False             False  False
# 4                          False             False  False
#
# [5 rows x 5737 columns]

# %%
df_encoded.shape
# Out:
# (72391, 5737)

# %% [markdown]
# Each row is a user, each column is a book, 1 = reviewed, 0 = not reviewed

# %% [markdown]
# ## Apply the Apriori Algorithm

# %% [markdown]
# Now, let’s find frequent book sets (books that users tend to review together).

# %% [markdown]
# If I set min_support=0.001, that means only book pairs occurring in at least 0,1% of transactions are considered.

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
frequent_itemsets = fpgrowth(df_encoded, min_support=0.0001, use_colnames=True)

# %%
# Find frequent itemsets with minimum support of 0.005
#frequent_itemsets = apriori(df_encoded, min_support=0.0001, use_colnames=True)

# Sort by support (higher support means more frequent co-occurrence)
frequent_itemsets = frequent_itemsets.sort_values(by="support", ascending=False)

# Display top 10 frequent itemsets
print(frequent_itemsets.head(10))
# Out:
#       support                                           itemsets
# 1    0.050600            (Harry Potter and The Sorcerer's Stone)
# 2    0.049398                                       (The Hobbit)
# 4    0.025901                                        (The Giver)
# 14   0.021798                                            (Night)
# 115  0.021315          (Harry Potter and the Chamber of Secrets)
# 146  0.017571                     (Eldest (Inheritance, Book 2))
# 16   0.017046                                            (Holes)
# 98   0.011396                                   (Goodnight Moon)
# 42   0.011314  (Me Talk Pretty One Day (Turtleback School & L...
# 7    0.009766                                (The Secret Garden)

# %% [markdown]
# interpretation:
# - 4.9% of users reviewed Harry Potter and The Sorcerer's Stone
# - 4.8% reviewed The Hobbit
# - 2.5% reviewed The Giver
# - 2.1% reviewed Night

# %% [markdown]
# ## Generate Association Rules

# %% [markdown]
# To make meaningful recommendations, let’s generate association rules from the frequent itemsets.

# %%
# Generate association rules with minimum confidence of 0.1
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)

# Sort by confidence (higher confidence means stronger rule)
rules = rules.sort_values(by="confidence", ascending=False)

# Display top 10 association rules
rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].head(10)
# Out:
#                                            antecedents  \
# 8          (The witch of Blackbird Pond (A Dell book))
# 9    (The witch of blackbird pond (A Dell yearling ...
# 11                       (The Witch of Blackbird Pond)
# 13                       (The Witch of Blackbird Pond)
# 15   (The witch of Blackbird Pond (A Dell book), Th...
# 3                (The Monster At The End Of This Book)
# 4                           (A visit from Santa Claus)
# 252  (The monster at the end of this book (A little...
# 253  (Where The Wild Things Are, The Monster At The...
# 257  (By the Shores of Silver Lake, Little House on...
#
#                                            consequents   support  confidence  \
# 8    (The witch of blackbird pond (A Dell yearling ...  0.003205         1.0
# 9          (The witch of Blackbird Pond (A Dell book))  0.003205         1.0
# 11   (The witch of blackbird pond (A Dell yearling ...  0.003177         1.0
# 13         (The witch of Blackbird Pond (A Dell book))  0.003177         1.0
# 15   (The witch of blackbird pond (A Dell yearling ...  0.003177         1.0
# 3    (The monster at the end of this book (A little...  0.004959         1.0
# 4    (The Night Before Christmas, The (Wee Books fo...  0.004517         1.0
# 252              (The Monster At The End Of This Book)  0.000124         1.0
# 253  (The monster at the end of this book (A little...  0.000124         1.0
# 257                      (Little House on the Prairie)  0.000124         1.0
#
#            lift
# 8    312.030172
# 9    312.030172
# 11   312.030172
# 13   312.030172
# 15   312.030172
# 3    199.424242
# 4    220.704268
# 252  201.646240
# 253  199.424242
# 257  731.222222
